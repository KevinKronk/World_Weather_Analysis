# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.0, 90, size=2000)
lngs = np.random.uniform(-180.0, 180.0, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 735

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather['coord']['lat']
        lng = city_weather['coord']['lon']
        max_temp = city_weather['main']['temp_max']
        humidity = city_weather['main']['humidity']
        cloudiness = city_weather['clouds']['all']
        wind = city_weather['wind']['speed']
        country = city_weather['sys']['country']
        weather_desc = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": lat,
                         "Lng": lng,
                         "Max Temp": max_temp,
                         "Humidity": humidity,
                         "Cloudiness": cloudiness,
                         "Wind Speed": wind,
                         "Country": country,
                         "Current Description": weather_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | westpunt
# City not found. Skipping...
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | eyl
# Processing Record 7 of Set 1 | iracoubo
# Processing Record 8 of Set 1 | cuamba
# Processing Record 9 of Set 1 | saldanha
# Processing Record 10 of Set 1 | husavik
# Processing Record 11 of Set 1 | marevo
# Processing Record 12 of Set 1 | monte san giovanni campano
# Processing Record 13 of Set 1 | darhan
# Processing Record 14 of Set 1 | cayenne
# Processing Record 15 of Set 1 | fukue
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | labuhan
# Processing Record 20 of Set 1 | pevek
# Processing Record 21 of Set 1 | pemangkat
# Processing Record 22 of Set 1 | kalabo
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | longyearbyen
# Processing Record 26 of Set 1 | akyab
# Processing Record 27 of Set 1 | katsuura
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | lagoa
# Processing Record 30 of Set 1 | sioux lookout
# Processing Record 31 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 32 of Set 1 | lorengau
# Processing Record 33 of Set 1 | moose factory
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | mahibadhoo
# Processing Record 37 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 1 | machaneng
# Processing Record 39 of Set 1 | rubik
# Processing Record 40 of Set 1 | turukhansk
# Processing Record 41 of Set 1 | ulaanbaatar
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | aqtobe
# Processing Record 45 of Set 1 | grand gaube
# Processing Record 46 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 1 | lazurne
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | miyako
# Processing Record 50 of Set 1 | powell river
# Processing Record 1 of Set 2 | tuatapere
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | margate
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | bilibino
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | vila velha
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | karratha
# Processing Record 11 of Set 2 | mehran
# Processing Record 12 of Set 2 | klaksvik
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | matongo
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | farmington
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 2 | san cristobal
# Processing Record 20 of Set 2 | salamanca
# Processing Record 21 of Set 2 | kruisfontein
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | srednekolymsk
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | jiexiu
# Processing Record 29 of Set 2 | adilcevaz
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | clyde river
# Processing Record 32 of Set 2 | portland
# Processing Record 33 of Set 2 | kozan
# Processing Record 34 of Set 2 | malatya
# Processing Record 35 of Set 2 | muros
# Processing Record 36 of Set 2 | khvoynaya
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | ambilobe
# Processing Record 39 of Set 2 | pades
# Processing Record 40 of Set 2 | henties bay
# Processing Record 41 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | batesville
# Processing Record 44 of Set 2 | adrar
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | aklavik
# Processing Record 48 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 2 | albany
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | dabat
# Processing Record 2 of Set 3 | kununurra
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | nishihara
# Processing Record 6 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | paso de carrasco
# Processing Record 9 of Set 3 | elbistan
# Processing Record 10 of Set 3 | cabo san lucas
# Processing Record 11 of Set 3 | saint-augustin
# Processing Record 12 of Set 3 | tingo maria
# Processing Record 13 of Set 3 | palmas bellas
# Processing Record 14 of Set 3 | liverpool
# Processing Record 15 of Set 3 | adre
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | rio grande
# Processing Record 18 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | ozernovskiy
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | camacha
# Processing Record 23 of Set 3 | tobermory
# Processing Record 24 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 25 of Set 3 | olafsvik
# Processing Record 26 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 3 | xapuri
# Processing Record 28 of Set 3 | anadyr
# Processing Record 29 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 3 | bodden town
# Processing Record 31 of Set 3 | yulara
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 3 | khatanga
# Processing Record 35 of Set 3 | pullman
# Processing Record 36 of Set 3 | berlevag
# Processing Record 37 of Set 3 | helsinki
# Processing Record 38 of Set 3 | kupang
# Processing Record 39 of Set 3 | kenai
# Processing Record 40 of Set 3 | jati
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 43 of Set 3 | tomatlan
# Processing Record 44 of Set 3 | waitati
# Processing Record 45 of Set 3 | soto
# Processing Record 46 of Set 3 | ulladulla
# Processing Record 47 of Set 3 | hnaberd
# Processing Record 48 of Set 3 | mar del plata
# Processing Record 49 of Set 3 | puerto escondido
# Processing Record 50 of Set 3 | obidos
# Processing Record 1 of Set 4 | caravelas
# Processing Record 2 of Set 4 | havelock
# Processing Record 3 of Set 4 | arraial do cabo
# Processing Record 4 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 4 | garden city
# Processing Record 6 of Set 4 | khandyga
# Processing Record 7 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 4 | lata
# Processing Record 9 of Set 4 | ponta do sol
# Processing Record 10 of Set 4 | georgetown
# Processing Record 11 of Set 4 | chokurdakh
# Processing Record 12 of Set 4 | marrakesh
# Processing Record 13 of Set 4 | mackay
# Processing Record 14 of Set 4 | korla
# Processing Record 15 of Set 4 | turinsk
# Processing Record 16 of Set 4 | san patricio
# Processing Record 17 of Set 4 | koslan
# Processing Record 18 of Set 4 | verkhnetulomskiy
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | amapa
# Processing Record 21 of Set 4 | savalou
# Processing Record 22 of Set 4 | sunamganj
# City not found. Skipping...
# Processing Record 23 of Set 4 | ostrovnoy
# Processing Record 24 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 4 | guerrero negro
# Processing Record 26 of Set 4 | bambanglipuro
# Processing Record 27 of Set 4 | ozinki
# Processing Record 28 of Set 4 | fushun
# Processing Record 29 of Set 4 | rocha
# Processing Record 30 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 4 | dauphin
# Processing Record 32 of Set 4 | charters towers
# Processing Record 33 of Set 4 | kailua
# Processing Record 34 of Set 4 | upernavik
# Processing Record 35 of Set 4 | mehamn
# Processing Record 36 of Set 4 | chuy
# Processing Record 37 of Set 4 | yellowknife
# Processing Record 38 of Set 4 | bonthe
# Processing Record 39 of Set 4 | whitefish
# Processing Record 40 of Set 4 | coihaique
# Processing Record 41 of Set 4 | turmalina
# Processing Record 42 of Set 4 | yakuplu
# Processing Record 43 of Set 4 | kholodnyy
# Processing Record 44 of Set 4 | ancud
# Processing Record 45 of Set 4 | san ignacio
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | port-cartier
# Processing Record 48 of Set 4 | hambantota
# Processing Record 49 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 50 of Set 4 | santa isabel do rio negro
# Processing Record 1 of Set 5 | dangara
# Processing Record 2 of Set 5 | makinsk
# Processing Record 3 of Set 5 | acapulco
# Processing Record 4 of Set 5 | concepcion del oro
# Processing Record 5 of Set 5 | riyadh
# Processing Record 6 of Set 5 | taga
# Processing Record 7 of Set 5 | cozumel
# Processing Record 8 of Set 5 | iralaya
# Processing Record 9 of Set 5 | big rapids
# Processing Record 10 of Set 5 | ilulissat
# Processing Record 11 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 5 | ngama
# Processing Record 13 of Set 5 | khash
# Processing Record 14 of Set 5 | ajdabiya
# Processing Record 15 of Set 5 | iskateley
# Processing Record 16 of Set 5 | batemans bay
# Processing Record 17 of Set 5 | cedar city
# Processing Record 18 of Set 5 | bose
# Processing Record 19 of Set 5 | santiago
# Processing Record 20 of Set 5 | gat
# Processing Record 21 of Set 5 | chara
# Processing Record 22 of Set 5 | ribeira grande
# Processing Record 23 of Set 5 | sao filipe
# Processing Record 24 of Set 5 | bijie
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | chunskiy
# Processing Record 27 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | tamale
# Processing Record 30 of Set 5 | mbini
# Processing Record 31 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 32 of Set 5 | anloga
# Processing Record 33 of Set 5 | quelimane
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | qaanaaq
# Processing Record 36 of Set 5 | saint george
# Processing Record 37 of Set 5 | bongandanga
# Processing Record 38 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 5 | cidreira
# Processing Record 40 of Set 5 | provideniya
# Processing Record 41 of Set 5 | faanui
# Processing Record 42 of Set 5 | staryy nadym
# Processing Record 43 of Set 5 | kirakira
# Processing Record 44 of Set 5 | cap malheureux
# Processing Record 45 of Set 5 | kavieng
# Processing Record 46 of Set 5 | komsomolskiy
# Processing Record 47 of Set 5 | shahrud
# Processing Record 48 of Set 5 | geraldton
# Processing Record 49 of Set 5 | asahikawa
# Processing Record 50 of Set 5 | atar
# Processing Record 1 of Set 6 | marsa matruh
# Processing Record 2 of Set 6 | alta floresta
# Processing Record 3 of Set 6 | clarence town
# Processing Record 4 of Set 6 | kayerkan
# Processing Record 5 of Set 6 | porto novo
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | shimoda
# Processing Record 8 of Set 6 | sandpoint
# Processing Record 9 of Set 6 | butaritari
# Processing Record 10 of Set 6 | naze
# Processing Record 11 of Set 6 | zharkent
# Processing Record 12 of Set 6 | khasan
# Processing Record 13 of Set 6 | kahului
# Processing Record 14 of Set 6 | galesong
# Processing Record 15 of Set 6 | wanaka
# Processing Record 16 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 17 of Set 6 | amancio
# City not found. Skipping...
# Processing Record 18 of Set 6 | kambove
# Processing Record 19 of Set 6 | ushumun
# Processing Record 20 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 6 | bartlesville
# Processing Record 22 of Set 6 | fuyang
# Processing Record 23 of Set 6 | miri
# Processing Record 24 of Set 6 | segezha
# Processing Record 25 of Set 6 | hualmay
# Processing Record 26 of Set 6 | constitucion
# Processing Record 27 of Set 6 | chunhuhub
# Processing Record 28 of Set 6 | el wasta
# City not found. Skipping...
# Processing Record 29 of Set 6 | baie-saint-paul
# Processing Record 30 of Set 6 | fort nelson
# Processing Record 31 of Set 6 | shelburne
# Processing Record 32 of Set 6 | pisco
# Processing Record 33 of Set 6 | wolmaranstad
# City not found. Skipping...
# Processing Record 34 of Set 6 | sinnamary
# Processing Record 35 of Set 6 | airai
# Processing Record 36 of Set 6 | manggar
# Processing Record 37 of Set 6 | porto-vecchio
# Processing Record 38 of Set 6 | iqaluit
# Processing Record 39 of Set 6 | kogon
# Processing Record 40 of Set 6 | miraflores
# Processing Record 41 of Set 6 | kieta
# Processing Record 42 of Set 6 | lavrentiya
# Processing Record 43 of Set 6 | tasiilaq
# Processing Record 44 of Set 6 | edd
# Processing Record 45 of Set 6 | sao miguel do araguaia
# Processing Record 46 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 6 | santa cruz
# Processing Record 48 of Set 6 | plerin
# Processing Record 49 of Set 6 | sapa
# Processing Record 50 of Set 6 | isangel
# Processing Record 1 of Set 7 | fortuna
# Processing Record 2 of Set 7 | norman wells
# Processing Record 3 of Set 7 | lodja
# Processing Record 4 of Set 7 | coos bay
# Processing Record 5 of Set 7 | jalu
# Processing Record 6 of Set 7 | damaturu
# Processing Record 7 of Set 7 | pudozh
# Processing Record 8 of Set 7 | obo
# Processing Record 9 of Set 7 | vardo
# Processing Record 10 of Set 7 | barao de melgaco
# Processing Record 11 of Set 7 | broken hill
# Processing Record 12 of Set 7 | shwebo
# Processing Record 13 of Set 7 | la ronge
# Processing Record 14 of Set 7 | ayorou
# Processing Record 15 of Set 7 | sambava
# Processing Record 16 of Set 7 | san juan de la maguana
# Processing Record 17 of Set 7 | polunochnoye
# Processing Record 18 of Set 7 | hue
# Processing Record 19 of Set 7 | pombia
# Processing Record 20 of Set 7 | kirkenaer
# Processing Record 21 of Set 7 | syracuse
# Processing Record 22 of Set 7 | litovko
# Processing Record 23 of Set 7 | lake city
# Processing Record 24 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 7 | juneau
# Processing Record 26 of Set 7 | baymak
# Processing Record 27 of Set 7 | tuy hoa
# Processing Record 28 of Set 7 | alibag
# Processing Record 29 of Set 7 | araouane
# Processing Record 30 of Set 7 | maniitsoq
# Processing Record 31 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 32 of Set 7 | cockburn town
# Processing Record 33 of Set 7 | jackson
# Processing Record 34 of Set 7 | alugan
# Processing Record 35 of Set 7 | carnarvon
# Processing Record 36 of Set 7 | vathi
# Processing Record 37 of Set 7 | leningradskiy
# Processing Record 38 of Set 7 | antropovo
# Processing Record 39 of Set 7 | yar-sale
# Processing Record 40 of Set 7 | ilhabela
# Processing Record 41 of Set 7 | shchuchye
# City not found. Skipping...
# Processing Record 42 of Set 7 | mnogovershinnyy
# Processing Record 43 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 7 | mmathubudukwane
# Processing Record 46 of Set 7 | dungarpur
# Processing Record 47 of Set 7 | sakakah
# Processing Record 48 of Set 7 | staraya mayna
# Processing Record 49 of Set 7 | baruun-urt
# Processing Record 50 of Set 7 | loiza
# Processing Record 1 of Set 8 | novyy urgal
# Processing Record 2 of Set 8 | outjo
# Processing Record 3 of Set 8 | kaminokawa
# Processing Record 4 of Set 8 | talnakh
# Processing Record 5 of Set 8 | avera
# Processing Record 6 of Set 8 | churapcha
# Processing Record 7 of Set 8 | athabasca
# Processing Record 8 of Set 8 | bluefield
# Processing Record 9 of Set 8 | port hardy
# Processing Record 10 of Set 8 | hasaki
# Processing Record 11 of Set 8 | awbari
# Processing Record 12 of Set 8 | okhotsk
# Processing Record 13 of Set 8 | crestview
# Processing Record 14 of Set 8 | bayeux
# Processing Record 15 of Set 8 | kirovskiy
# Processing Record 16 of Set 8 | salinopolis
# Processing Record 17 of Set 8 | sechura
# Processing Record 18 of Set 8 | siirt
# Processing Record 19 of Set 8 | ketchikan
# Processing Record 20 of Set 8 | neiafu
# Processing Record 21 of Set 8 | aksarka
# Processing Record 22 of Set 8 | tairua
# Processing Record 23 of Set 8 | poso
# Processing Record 24 of Set 8 | walvis bay
# Processing Record 25 of Set 8 | torbay
# Processing Record 26 of Set 8 | zasechnoye
# Processing Record 27 of Set 8 | doba
# Processing Record 28 of Set 8 | alyangula
# Processing Record 29 of Set 8 | thinadhoo
# Processing Record 30 of Set 8 | saint-pierre
# Processing Record 31 of Set 8 | porterville
# Processing Record 32 of Set 8 | ye
# City not found. Skipping...
# Processing Record 33 of Set 8 | ayia marina
# Processing Record 34 of Set 8 | dwarka
# Processing Record 35 of Set 8 | elko
# Processing Record 36 of Set 8 | mount gambier
# Processing Record 37 of Set 8 | high prairie
# Processing Record 38 of Set 8 | nayoro
# Processing Record 39 of Set 8 | tessalit
# Processing Record 40 of Set 8 | san francisco
# Processing Record 41 of Set 8 | touros
# Processing Record 42 of Set 8 | lompoc
# Processing Record 43 of Set 8 | wuwei
# Processing Record 44 of Set 8 | leshukonskoye
# Processing Record 45 of Set 8 | port lincoln
# Processing Record 46 of Set 8 | aykhal
# Processing Record 47 of Set 8 | bac lieu
# Processing Record 48 of Set 8 | marsh harbour
# Processing Record 49 of Set 8 | skelleftea
# Processing Record 50 of Set 8 | peleduy
# Processing Record 1 of Set 9 | newport
# Processing Record 2 of Set 9 | nanortalik
# Processing Record 3 of Set 9 | buritis
# Processing Record 4 of Set 9 | krasnoshchekovo
# Processing Record 5 of Set 9 | kutum
# Processing Record 6 of Set 9 | coquimbo
# Processing Record 7 of Set 9 | dingle
# Processing Record 8 of Set 9 | shakawe
# Processing Record 9 of Set 9 | vani
# Processing Record 10 of Set 9 | south yuba city
# Processing Record 11 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 9 | beloha
# Processing Record 13 of Set 9 | arrifes
# Processing Record 14 of Set 9 | taoudenni
# Processing Record 15 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 9 | cabatuan
# Processing Record 17 of Set 9 | merauke
# Processing Record 18 of Set 9 | conceicao do araguaia
# Processing Record 19 of Set 9 | gunjur
# Processing Record 20 of Set 9 | aleksandrovka
# Processing Record 21 of Set 9 | axim
# Processing Record 22 of Set 9 | palmer
# Processing Record 23 of Set 9 | gayny
# Processing Record 24 of Set 9 | delitzsch
# Processing Record 25 of Set 9 | grindavik
# Processing Record 26 of Set 9 | hofn
# Processing Record 27 of Set 9 | mattawa
# Processing Record 28 of Set 9 | porto velho
# Processing Record 29 of Set 9 | kushima
# Processing Record 30 of Set 9 | sirsi
# Processing Record 31 of Set 9 | ornskoldsvik
# Processing Record 32 of Set 9 | marzuq
# Processing Record 33 of Set 9 | sarrebourg
# Processing Record 34 of Set 9 | usinsk
# Processing Record 35 of Set 9 | goderich
# Processing Record 36 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 9 | ouallam
# Processing Record 38 of Set 9 | inhambane
# Processing Record 39 of Set 9 | la asuncion
# Processing Record 40 of Set 9 | alekseyevsk
# Processing Record 41 of Set 9 | solnechnyy
# Processing Record 42 of Set 9 | beringovskiy
# Processing Record 43 of Set 9 | roseburg
# Processing Record 44 of Set 9 | arouca
# Processing Record 45 of Set 9 | tigil
# Processing Record 46 of Set 9 | san andres
# Processing Record 47 of Set 9 | luderitz
# Processing Record 48 of Set 9 | senekal
# Processing Record 49 of Set 9 | port moresby
# Processing Record 50 of Set 9 | daru
# Processing Record 1 of Set 10 | manbij
# Processing Record 2 of Set 10 | khani
# Processing Record 3 of Set 10 | mazara del vallo
# Processing Record 4 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 10 | kajaani
# Processing Record 6 of Set 10 | kyra
# Processing Record 7 of Set 10 | bandarbeyla
# Processing Record 8 of Set 10 | colares
# Processing Record 9 of Set 10 | kiunga
# Processing Record 10 of Set 10 | vanderhoof
# Processing Record 11 of Set 10 | pangnirtung
# Processing Record 12 of Set 10 | russell
# Processing Record 13 of Set 10 | savelugu
# Processing Record 14 of Set 10 | wakkanai
# Processing Record 15 of Set 10 | afmadu
# City not found. Skipping...
# Processing Record 16 of Set 10 | muscle shoals
# Processing Record 17 of Set 10 | kartaly
# Processing Record 18 of Set 10 | cochrane
# Processing Record 19 of Set 10 | balclutha
# Processing Record 20 of Set 10 | panaba
# Processing Record 21 of Set 10 | matay
# Processing Record 22 of Set 10 | souillac
# Processing Record 23 of Set 10 | bangkalan
# Processing Record 24 of Set 10 | whitehorse
# Processing Record 25 of Set 10 | rodrigues alves
# Processing Record 26 of Set 10 | tabuk
# Processing Record 27 of Set 10 | rosetta
# Processing Record 28 of Set 10 | tamandare
# Processing Record 29 of Set 10 | vila franca do campo
# Processing Record 30 of Set 10 | tateyama
# Processing Record 31 of Set 10 | christchurch
# Processing Record 32 of Set 10 | chernyshevskiy
# Processing Record 33 of Set 10 | hettstedt
# Processing Record 34 of Set 10 | rio gallegos
# Processing Record 35 of Set 10 | mongar
# Processing Record 36 of Set 10 | luorong
# Processing Record 37 of Set 10 | moussoro
# Processing Record 38 of Set 10 | zhuanghe
# Processing Record 39 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 40 of Set 10 | shizilu
# Processing Record 41 of Set 10 | asau
# Processing Record 42 of Set 10 | sterling
# Processing Record 43 of Set 10 | vao
# Processing Record 44 of Set 10 | tevriz
# Processing Record 45 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 46 of Set 10 | surskoye
# Processing Record 47 of Set 10 | nalgonda
# Processing Record 48 of Set 10 | atambua
# Processing Record 49 of Set 10 | alofi
# Processing Record 50 of Set 10 | vestmannaeyjar
# Processing Record 1 of Set 11 | lichinga
# Processing Record 2 of Set 11 | mezica
# Processing Record 3 of Set 11 | ngunguru
# Processing Record 4 of Set 11 | zhovtneve
# Processing Record 5 of Set 11 | san juan
# Processing Record 6 of Set 11 | kharan
# Processing Record 7 of Set 11 | mwinilunga
# Processing Record 8 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 11 | villa rica
# Processing Record 10 of Set 11 | kiama
# Processing Record 11 of Set 11 | haines junction
# Processing Record 12 of Set 11 | oranjemund
# Processing Record 13 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 14 of Set 11 | kuryk
# Processing Record 15 of Set 11 | port keats
# Processing Record 16 of Set 11 | carora
# Processing Record 17 of Set 11 | krasnoselkup
# Processing Record 18 of Set 11 | kumbo
# Processing Record 19 of Set 11 | den helder
# Processing Record 20 of Set 11 | los llanos de aridane
# Processing Record 21 of Set 11 | lewiston
# Processing Record 22 of Set 11 | bathsheba
# Processing Record 23 of Set 11 | kosonsoy
# Processing Record 24 of Set 11 | arkhipo-osipovka
# Processing Record 25 of Set 11 | pathein
# Processing Record 26 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 11 | tamiahua
# Processing Record 28 of Set 11 | labrea
# Processing Record 29 of Set 11 | nushki
# Processing Record 30 of Set 11 | visby
# Processing Record 31 of Set 11 | hamilton
# Processing Record 32 of Set 11 | hai phong
# City not found. Skipping...
# Processing Record 33 of Set 11 | faya
# Processing Record 34 of Set 11 | puerto el triunfo
# Processing Record 35 of Set 11 | inuvik
# Processing Record 36 of Set 11 | tiznit
# Processing Record 37 of Set 11 | alanya
# Processing Record 38 of Set 11 | riviere-au-renard
# Processing Record 39 of Set 11 | poltavka
# Processing Record 40 of Set 11 | juba
# Processing Record 41 of Set 11 | detchino
# Processing Record 42 of Set 11 | roma
# Processing Record 43 of Set 11 | ismailia
# Processing Record 44 of Set 11 | arica
# Processing Record 45 of Set 11 | bilma
# Processing Record 46 of Set 11 | burica
# City not found. Skipping...
# Processing Record 47 of Set 11 | sabya
# Processing Record 48 of Set 11 | nchelenge
# Processing Record 49 of Set 11 | dhilwan
# Processing Record 50 of Set 11 | smederevo
# Processing Record 1 of Set 12 | tupelo
# Processing Record 2 of Set 12 | elin pelin
# Processing Record 3 of Set 12 | leh
# Processing Record 4 of Set 12 | ayolas
# Processing Record 5 of Set 12 | waingapu
# Processing Record 6 of Set 12 | saint-andre-avellin
# Processing Record 7 of Set 12 | a
# City not found. Skipping...
# Processing Record 8 of Set 12 | oussouye
# Processing Record 9 of Set 12 | helong
# Processing Record 10 of Set 12 | rawson
# Processing Record 11 of Set 12 | sola
# Processing Record 12 of Set 12 | hargeysa
# Processing Record 13 of Set 12 | cortez
# Processing Record 14 of Set 12 | pomichna
# Processing Record 15 of Set 12 | tukrah
# Processing Record 16 of Set 12 | keetmanshoop
# Processing Record 17 of Set 12 | samarai
# Processing Record 18 of Set 12 | kerman
# Processing Record 19 of Set 12 | byron bay
# Processing Record 20 of Set 12 | qui nhon
# Processing Record 21 of Set 12 | shaowu
# Processing Record 22 of Set 12 | mirnyy
# Processing Record 23 of Set 12 | poya
# Processing Record 24 of Set 12 | broome
# Processing Record 25 of Set 12 | ureki
# Processing Record 26 of Set 12 | strezhevoy
# Processing Record 27 of Set 12 | deulgaon raja
# Processing Record 28 of Set 12 | kerema
# Processing Record 29 of Set 12 | port blair
# Processing Record 30 of Set 12 | la palma
# Processing Record 31 of Set 12 | floro
# Processing Record 32 of Set 12 | nelson bay
# Processing Record 33 of Set 12 | talcahuano
# Processing Record 34 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 12 | lachi
# Processing Record 36 of Set 12 | abnub
# Processing Record 37 of Set 12 | buala
# Processing Record 38 of Set 12 | carlagan
# Processing Record 39 of Set 12 | soyo
# Processing Record 40 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 12 | eureka
# Processing Record 42 of Set 12 | olinda
# Processing Record 43 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 12 | nadym
# Processing Record 45 of Set 12 | sorland
# Processing Record 46 of Set 12 | otane
# Processing Record 47 of Set 12 | abu dhabi
# Processing Record 48 of Set 12 | mpika
# Processing Record 49 of Set 12 | shenzhen
# Processing Record 50 of Set 12 | saint-georges
# Processing Record 1 of Set 13 | anyksciai
# Processing Record 2 of Set 13 | patancheru
# Processing Record 3 of Set 13 | aksu
# Processing Record 4 of Set 13 | salihorsk
# Processing Record 5 of Set 13 | nuuk
# Processing Record 6 of Set 13 | ocala
# Processing Record 7 of Set 13 | pandan
# Processing Record 8 of Set 13 | khuzhir
# Processing Record 9 of Set 13 | cabedelo
# Processing Record 10 of Set 13 | norton
# Processing Record 11 of Set 13 | mogadishu
# Processing Record 12 of Set 13 | los banos
# Processing Record 13 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 13 | bacolod
# Processing Record 15 of Set 13 | pattaya
# Processing Record 16 of Set 13 | marystown
# Processing Record 17 of Set 13 | boa vista
# Processing Record 18 of Set 13 | aginskoye
# Processing Record 19 of Set 13 | forestville
# Processing Record 20 of Set 13 | acari
# Processing Record 21 of Set 13 | tual
# Processing Record 22 of Set 13 | noumea
# Processing Record 23 of Set 13 | nagapattinam
# Processing Record 24 of Set 13 | magadan
# Processing Record 25 of Set 13 | weihe
# Processing Record 26 of Set 13 | champlin
# Processing Record 27 of Set 13 | macaubas
# Processing Record 28 of Set 13 | abomey
# Processing Record 29 of Set 13 | teteven
# Processing Record 30 of Set 13 | biograd na moru
# Processing Record 31 of Set 13 | sholavandan
# City not found. Skipping...
# Processing Record 32 of Set 13 | ebensee
# Processing Record 33 of Set 13 | panguna
# Processing Record 34 of Set 13 | salinas
# Processing Record 35 of Set 13 | arroio grande
# Processing Record 36 of Set 13 | orange
# Processing Record 37 of Set 13 | sur
# Processing Record 38 of Set 13 | kalaleh
# Processing Record 39 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 13 | jiuquan
# Processing Record 41 of Set 13 | lubango
# Processing Record 42 of Set 13 | dalbandin
# Processing Record 43 of Set 13 | nanao
# Processing Record 44 of Set 13 | kasama
# Processing Record 45 of Set 13 | talara
# Processing Record 46 of Set 13 | pyay
# Processing Record 47 of Set 13 | wenatchee
# Processing Record 48 of Set 13 | nichinan
# Processing Record 49 of Set 13 | staromaryevka
# City not found. Skipping...
# Processing Record 50 of Set 13 | songjianghe
# Processing Record 1 of Set 14 | oktyabrskiy
# Processing Record 2 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 14 | berdigestyakh
# Processing Record 4 of Set 14 | xilagani
# Processing Record 5 of Set 14 | badiraguato
# Processing Record 6 of Set 14 | svetlaya
# Processing Record 7 of Set 14 | katiola
# Processing Record 8 of Set 14 | platteville
# Processing Record 9 of Set 14 | morondava
# Processing Record 10 of Set 14 | padang
# Processing Record 11 of Set 14 | havre-saint-pierre
# Processing Record 12 of Set 14 | lhokseumawe
# Processing Record 13 of Set 14 | toora-khem
# Processing Record 14 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 14 | kenitra
# Processing Record 16 of Set 14 | pointe michel
# Processing Record 17 of Set 14 | sokol
# Processing Record 18 of Set 14 | klichka
# Processing Record 19 of Set 14 | tura
# Processing Record 20 of Set 14 | havoysund
# Processing Record 21 of Set 14 | davila
# Processing Record 22 of Set 14 | novaya malykla
# Processing Record 23 of Set 14 | agadir
# Processing Record 24 of Set 14 | sete
# Processing Record 25 of Set 14 | luganville
# Processing Record 26 of Set 14 | vana-vigala
# Processing Record 27 of Set 14 | honiara
# Processing Record 28 of Set 14 | cauquenes
# Processing Record 29 of Set 14 | guiratinga
# Processing Record 30 of Set 14 | lubaczow
# Processing Record 31 of Set 14 | vostochnyy
# Processing Record 32 of Set 14 | ust-omchug
# Processing Record 33 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 14 | les cayes
# Processing Record 35 of Set 14 | sept-iles
# Processing Record 36 of Set 14 | ahipara
# Processing Record 37 of Set 14 | sinjar
# Processing Record 38 of Set 14 | kisangani
# Processing Record 39 of Set 14 | santa rosalia
# Processing Record 40 of Set 14 | florida
# Processing Record 41 of Set 14 | namibe
# Processing Record 42 of Set 14 | abu kamal
# Processing Record 43 of Set 14 | bayan
# Processing Record 44 of Set 14 | mathbaria
# Processing Record 45 of Set 14 | maun
# Processing Record 46 of Set 14 | verkhniye kigi
# Processing Record 47 of Set 14 | pringsewu
# Processing Record 48 of Set 14 | camapua
# Processing Record 49 of Set 14 | san borja
# Processing Record 50 of Set 14 | dawei
# Processing Record 1 of Set 15 | douentza
# Processing Record 2 of Set 15 | point fortin
# Processing Record 3 of Set 15 | nago
# Processing Record 4 of Set 15 | wingham
# Processing Record 5 of Set 15 | mecca
# Processing Record 6 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 7 of Set 15 | egvekinot
# Processing Record 8 of Set 15 | moerai
# Processing Record 9 of Set 15 | zaysan
# Processing Record 10 of Set 15 | najran
# Processing Record 11 of Set 15 | brigantine
# Processing Record 12 of Set 15 | krasnyy oktyabr
# Processing Record 13 of Set 15 | brenham
# Processing Record 14 of Set 15 | lanxi
# Processing Record 15 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 16 of Set 15 | tocopilla
# Processing Record 17 of Set 15 | filingue
# Processing Record 18 of Set 15 | laguna
# Processing Record 19 of Set 15 | chalmette
# Processing Record 20 of Set 15 | ziyamet
# City not found. Skipping...
# Processing Record 21 of Set 15 | dalvik
# Processing Record 22 of Set 15 | changping
# Processing Record 23 of Set 15 | singaraja
# Processing Record 24 of Set 15 | borogontsy
# Processing Record 25 of Set 15 | flinders
# Processing Record 26 of Set 15 | altamira
# Processing Record 27 of Set 15 | shenkursk
# Processing Record 28 of Set 15 | timmins
# Processing Record 29 of Set 15 | nuevitas
# Processing Record 30 of Set 15 | el alto
# Processing Record 31 of Set 15 | pokhara
# Processing Record 32 of Set 15 | bafq
# Processing Record 33 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 15 | belyy yar
# Processing Record 35 of Set 15 | alice springs
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 671

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Nikolskoye  59.7035  30.7861     44.80        96          79        3.06
# 1  Puerto Ayora  -0.7393 -90.3518     66.54        94          27        5.99
# 2     Mahebourg -20.4081  57.7000     68.29        83          40        4.61
# 3       Ushuaia -54.8000 -68.3000     44.26        87          75       11.50
# 4           Eyl   7.9803  49.8164     76.10        83          35       11.18
# 5      Iracoubo   5.4802 -53.2011     79.41        81           9       10.67
# 6        Cuamba -14.8031  36.5372     68.86        33           8        3.62
# 7      Saldanha -33.0117  17.9442     46.45        70           0       10.78
# 8       Husavik  66.0449 -17.3389     41.27        98         100       21.83
# 9        Marevo  57.3146  32.0804     40.37        96         100        2.91
#
#   Country Current Description
# 0      RU          light rain
# 1      EC    scattered clouds
# 2      MU    scattered clouds
# 3      AR       moderate rain
# 4      SO    scattered clouds
# 5      GF           clear sky
# 6      MZ           clear sky
# 7      ZA           clear sky
# 8      IS     overcast clouds
# 9      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 
                    'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nikolskoye      RU  59.7035  30.7861     44.80        96          79
# 1  Puerto Ayora      EC  -0.7393 -90.3518     66.54        94          27
# 2     Mahebourg      MU -20.4081  57.7000     68.29        83          40
# 3       Ushuaia      AR -54.8000 -68.3000     44.26        87          75
# 4           Eyl      SO   7.9803  49.8164     76.10        83          35
# 5      Iracoubo      GF   5.4802 -53.2011     79.41        81           9
# 6        Cuamba      MZ -14.8031  36.5372     68.86        33           8
# 7      Saldanha      ZA -33.0117  17.9442     46.45        70           0
# 8       Husavik      IS  66.0449 -17.3389     41.27        98         100
# 9        Marevo      RU  57.3146  32.0804     40.37        96         100
#
#    Wind Speed Current Description
# 0        3.06          light rain
# 1        5.99    scattered clouds
# 2        4.61    scattered clouds
# 3       11.50       moderate rain
# 4       11.18    scattered clouds
# 5       10.67           clear sky
# 6        3.62           clear sky
# 7       10.78           clear sky
# 8       21.83     overcast clouds
# 9        2.91     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
